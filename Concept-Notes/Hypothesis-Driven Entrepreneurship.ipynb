# %% [markdown]
# * hypothesis driven approach to entrepreneurship maximizes, per unit resources expended, the amount of information gained for resolving uncertainty
# * translate vision into falsifiable business model, then test them using MVPs
#     * mvp: smallest set of activities to disprove a hypothesis
# * the goal is to reach product-market fit
#     * 3 ps: perservere, perish, pivot
# * biggest risk of entrepreneurs: creating something no one wants
# * growth is not a primary objective, but creating a sustainable business - bounding uncertainty before scaling

# %% [markdown]
# ### guidelines for ideation
# * immersion - closely observing and interacting with customers
# * obsession
# * incubation - spend years on the problem, let the subconscious do the work
# * recombination - connecting unrelated concepts
# * clarification - refine idea into strucutre
# * collaboration

# %% [markdown]
# ### typology of pivots
# * value prop - feature set
# * value prop - customer set
# * GTM
# * cash flow formula

# %% [markdown]
# ### hypothesis driven entrepreneurship - process steps
# * 3 other approaches to lean:
#     * build it and they will come - bypass customer feedback
#     * waterfall planning - completing product dev in sequence (serial)
#     * just do it - improvisational approach, no plan
# * translate vision into falsifiable business model
#     * business model - integrated array of distinctive choices specifying a new venture's customer value prop

# %%
from IPython.display import Image
Image("pics/hypothesis_driven_entrepreneurshio_diagram.png")

# %%
Image("pics/hypothesis_driven_entrepreneurship_business_model_aspects.png")

# %% [markdown]
# ### important aspects of the hypothesis
# * falsifiability - when it can be rejected with a decisive experiemnt
#     * generate hypothesis that requires quantative metrics
#     * cohort analysis - track LTV and CAC
# * comprehensitiveness - don't need to be complete

# %% [markdown]
# ### specify MVPs
# * the smallest set of features needed to complete what's called build-measure-learn
# * reduces product development batch sizes and
# * 2 benefits:
#     * accelerate feedback and learnings
#     * easier to interpret test results because incremental changes, which also accelerates learning
# * factors:
#     * constrained functionality
#     * constrained operations
#     * series of mvps - incremental learnings
#     * constrained customer set
#     * false positive and negative results - results are random variables

# %% [markdown]
# ### prioritize tests
# * prioritize tests to eliminate risks at low costs
# * factors
#     * parallel testing
