# %% [markdown]
# [src](https://www.sec.gov/Archives/edgar/data/1639920/000119312518063434/d494294df1.htm)

# %% [markdown]
# ### summary
# * founded in 2008
# * music industry rev was in decline, from 24B (1999) to 18B (2008)
# * needed a legal simpler way to listen to music
# * music subscription service
#     * ad supported service, no fees
#     * premium, has fees
# * 159 MM MAU, 71 MM premium subs
# * rev = subs + ads
# * YoY rev growth of 45%
# * music industry is reversing decline via streaming
#     * SPOT is the biggest streaming service
# * how is it different?
#     * personalization via data scale play
#     * better UX
#     * Spotify Playlists are the Driving Force Behind Music Discovery and Demand Creation on our Service
# * building a 2-sided market
# * benefits for users
#     * playlists and personalization
#     * Ad-Supported Service, Family Plan, Student Plan, and individual Premium subscriptions
#         * student - supported to convert to premium
#         * family - to prevent acc sharing
#     * cross pltform
# * benefits for creators
#     * monetization
#     * discovery
#     * distribution
#     * promotion (profile + targeting service)
#     * analytics
#     * creation
# * biz model
#     * premium and ad suppoert services
#     * higher engagement for users drive lower premium churn
#     * 5% churn rate per quarter
# * growth strategy
#     * improve platform
#     * increase existing penetration (13% of smartphones atm)
#     * new geos
#     * improve advertising biz

# %%
from IPython.display import Image
Image("pics/spotify_finances.png")

# %%
Image("pics/spotify_kpis.png")

# %% [markdown]
# * notes:
#     * very high cost of revenue!, low margins
#     * heavily invested into sales and marketing
#         * marketing is prob ads / campaigns
#         * sales is prob to sell the ads

# %% [markdown]
# * cost of music
#     * With respect to mechanical rights, for example, in the United States, the rates we pay are, to a significant degree, a function of a ratemaking proceeding conducted by an administrative agency called the Copyright Royalty Board. The rates that the Copyright Royalty Board set apply both to compositions that we license under the compulsory license in Section 115 of the Copyright Act of 1976 (the “Copyright Act”), and to a number of direct licenses that we have with music publishers for U.S. rights, in which the applicable rate is generally pegged to the statutory rate set by the Copyright Royalty Board. The most recent proceeding before the Copyright Royalty Board (the “Phonorecords III Proceedings”) set the rates for the Section 115 compulsory license for calendar years 2018 to 2022. The Copyright Royalty Board issued its initial written determination on January 26, 2018. The rates set by the Copyright Royalty Board may still be modified if a party appeals the determination and are subject to further change as part of future Copyright Royalty Board proceedings. Based on management’s estimates and forecasts, we currently believe that the proposed rates will not materially impact our business, operating results, and financial condition. However, if our business does not perform as expected or if the rates are modified to be higher than the proposed rates, our content acquisition costs could increase and impact our ability to obtain content on pricing terms favorable to us, which could negatively harm our business, operating results, and financial condition and hinder our ability to provide interactive features in our services, or cause one or more of our services not to be economically viable.
#
# * have no rights to music..., depends on rates and negotiation
# * Certain of our license agreements for sound recordings and musical compositions (both for mechanical rights and public performance rights) contain minimum guarantees and/or require that we make minimum guarantee payments.
# * "sales and marketing, including a significant expansion of our field sales organization;"
# * competing with lots of other services, e.g. Amazon
# * lives on google cloud platform

# %% [markdown]
# * no underwriter
#     * pro:
#         * Spotify will not have to pay the substantial fees. What’s more, there will likely be more retail participation in the offering. Such investors tend to hold on to their holdings longer. And to top it off, Spotify has a large number of loyal customers that would definitely want to buy into the deal.
#     * con:
#         * no bankers to ensure that the stock pops from institutional buyers that sell on the first day
# * controlled by the founders (80%+ voting power)

# %% [markdown]
# * cap table
# * ARPU
#     * premium - 5 euro monthly
# * rev breakdown - 10% ads, 90% premium sub
# * premium has higher margins, YoY growth in margins is because of this

# %% [markdown]
# * marketing cost increase
#     * 570MM in 2017, advertising costs
