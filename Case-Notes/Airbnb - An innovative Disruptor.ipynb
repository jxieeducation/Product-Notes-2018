# %% [markdown]
# * Airbnb had poor rev, realized that photos were the problem, so offered professional services
# * prevented offline transactions
#     * deleted ways of contact from the message system (e.g. deleted phone #)

# %%
from IPython.display import Image
Image("pics/airbnb_biz_model.png")
