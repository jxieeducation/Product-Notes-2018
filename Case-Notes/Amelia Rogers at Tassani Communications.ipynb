# %% [markdown]
# * Amelia - account, Dave - creative director, setting - advertising agency
# * TC - marketing company - integrated (combines advertising, PR, direct marketing, sales...etc.)
# * sally Tassani - company founder, Jim Paglia - high level marketing executive
#     * worked together closely
#     * Tassani - new biz dev, Paglia - day to day
# * pains:
#     * harder to scale the agency beyond the key 2 people
#         * personalized services also is a bottleneck for scale
#     * some loyal employees without formal training were outgrown
#     * lack of prioritization when it comes to people management
#     * creative and account people have opposite contrainsts - cost and quality
#     * creatives always exceed budget

# %% [markdown]
# ## Organizational Structure and Creative Process

# %%
from IPython.display import Image
Image("pics/amelia_rogers_org_chart.png")

# %% [markdown]
# * department directors are held accountable for rev goals, but have profit measured together
#     * don't have individual budgets
#     * critical to aligning people
# * Sally Tassani gets new biz -> account director understands the work needed -> calls deps to scope out work needed
# * creative and account directors work out an outline to show to Paglia
# * Jim's job is to question and get the strongest possible idea and creative
# * the directors themselves usually don't act critically without meeting with Jim

# %% [markdown]
# ## Amelia Rogers
# * have a background at large places
# * wanted Jim to be hands on, but Jim is not
# * Rogers had a lot of meetings, wanted to be "at the other people's place", talked with clients, different directors and is integrated in the strategic review process
# * tough with the creatives
# * Burns conflict with Rogers because Rogers micromangages the creative's messaging, and Burns want control of his work
#
# ### Muffler World
# * auto service chain, wanted faster turnaround and new agency
# * Guy Johnson, Muffler World's CMO
# * Sparkman, a former employee of Muffler, moved to TC, and Johnson liked that the AM knows Muffler World inside out
# * Rogers is taking over Sparkman
#     * lacks Auto background, but Jim encourages Rogers
#     * Rogers is overbooked and has problem with cost-quality trade off

# %% [markdown]
# ## Dave Burns
# * liberal from startup experience
# * has 2 creative teams, working separately to avoid competition
# * very not strict with hierarchy
# * creative director translates account's assignment into creative concepts
#     * kind of like product managers
#     * wanted an account person with a creative background, but they are usually mbas with biz background
#     * pain point is that creatives don't understand things
# * perfers strategic parameters, e.g. constraints, to be creative
# * Burns defends his art people's work
# * sometimes he overdefends and doesn't see it and play politics well
# * Rogers triees to keep Burns informed

# %% [markdown]
# ## FSI assignment
# * "free assignment" - lots of liberal stuff
# * Burns wanted to do an illustration, Johnson from Muffler is getting cold feet from his boss
# * burns on short timeline
# * Burns calls Johnson directly about the project with cold feet, Johnson informs Rogers

# %% [markdown]
# ## should Rogers call in with Jim?
