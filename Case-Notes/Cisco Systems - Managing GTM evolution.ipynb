# %% [markdown]
# * cisco survived tech wreck by downsizing
# * made GTM better and more strategic

# %%
from IPython.display import Image
Image("pics/cisco_customer_pyramid.png")

# %% [markdown]
# ### startup
# * Stanford, invented multiprotocol router, manufacturing outsourced, indirect sales and distribution grew a lot
# * new channel blue print after dotcom crash:
#     * raised certification requirements, 6k to 3k partners
#     * 3 tiers of VARs, gold, silver, bronze, all discounts based on certification and specialization
#     * new var channel - value engagement
#
# ### switching and routing
# * routers and switches - a spectrum in complexity, switch - dumb, routers - smart
#
# ### routes to market

# %%
Image("pics/cisco_channel.png")

# %% [markdown]
# * channel 4 - traditional VAR focused on networking, 85% router market, 70% switch market
# * channel 5 - serve many small dispersed customers
# * channel 6 - added via acquisition of linksys for retail

# %% [markdown]
# * demand generation - AM and systems engineers - high touch
# * 22% rev was from channel's prospecting, 78% was from Cisco's SF
# * cisco market:
#     * corporate networking
#     * telecommunication services
#     * SMB networking

# %% [markdown]
# ### managing VAR channels
# * 3 tiers - 5% - Gold, 5% - Silver, 90% - premier, with different discount schemes
# * channel conflicts
#     * as pie shrank, saw consolidation and middle of market dying
#     * cross channel raiding - between telecom and networking, for e.g.
# * internet cahnnels
#     * online channels also ate up some of the market
#     * sold to SMBs
#     * complaint:
#         Cisco believed it was more efficient for someone who wanted to buy one item costing 1,000 or less to do it online. But a reseller said: “We have customers who would be buying 30 or more of these [products] as well as our design services and implementation. This program pegs the price and validates the online reseller with a preferred status. You can bet that all the big customers are going to be clicking there too.

# %% [markdown]
# ### channel reengineering
# * dropped sales volume req, instead had a pts system, that valued a variety of things, like technology
# * enabled small but highly specialized groups
#     * pts based on customer surveys as well for discounts
#     * no longer volume based for everything
# * caused lower channel conflicts
# * brought VARs into deals earlier
# *
