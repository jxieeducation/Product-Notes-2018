# %% [markdown]
# ### quotes
# * "as long as there is system integration required, it will be difficult to do direct sales"
# * https://www.forbes.com/sites/tomgillis/2014/08/05/wheres-the-value-going-to-be-in-value-added-resellers/#2cad88b94f36
#     * role of the VAR was to provide coverage in places the direct sales team couldn’t reach, to help with logistics such as warehousing, stocking, and credit checks, and to provide valuable integration and advisory services as an extension of IT teams to make all these complex boxes actually useful for the customer

# %% [markdown]
# * Vocera sold via 3rd party channel than direct
# * hard to convince VCs of selling via value-added-resellers (VAR)
# * concerns:
#     * how would company make investment pay off
#     * how owuld company have visiblity into sales pipeline?

# %% [markdown]
# ## About Vocera
# * voice communication system for hospitals, retail stores, buildings
# * channel of 25 VARs, most provide wireless LAN products, installation and services
# * badge + server + administration console
#     * software has speech recognition
#     * allows communication with hand free basis
# * pricing, rev, margins
#     * each badge is 350, software is SaaS
#     * 75 users, sell for 20k
#     * sell extensions as well, 5k for 6 ports
# * in the beginning, sold badges, but quickly realzied users share badges, so changed pricing since software charges per user

# %% [markdown]
# ## History
# * people with heavy communication / networking backgrounds
# * Julia disagreed with Vocera's strategy during CEO search:
#     * bluetooth
#     * horizontal market focus instead of niche verticals

# %% [markdown]
# ## Shimer's early initiatives
# * VC hated Vocera for 2 reasons
#     * used VARs instead of direct, which gave up visibility
#     * didn't like focus on hospitals which is complex for startups to navigate

# %% [markdown]
# ## Market
# ### Market size and growth projections
# * needed to install wireless LAN
# * highest wireless LAN adoption places:
#     * health care, retail, education
# * healthcare - labor intensive with resoruce constraints, operating inefficiencies and nursing shortages
# * current systems suck
#     * overhead paging, phones
# * retail also - inventory management needs
# * semi competitors: in-building wireless telephone systems

# %% [markdown]
# ## Establishing VAR channel
# * wanted VARs that:
#     * knowledgeable, skilled, enoguh traction to bring in sales, but not too large like IBM global solutions
# * characteristics:
#     * wireless lan installation exp
#     * industry focus on healthcare and retail
#     * understands Vocera's USP
#     * sales force of at least 10 ppl
#     * level of technical support is ok
# * 50 ish qualified
#
# ### signing vars
# * 30% var discount rate
#     * channel's discussion for pricing to consumer
# * each VAR is expected to sell 250k per year
#
# ### VAR training
# * 45 min web sales seminar
# * flwe them in and treated them well

# %%
from IPython.display import Image
Image("pics/vocera_relationships.png")

# %% [markdown]
# ### building VAR relationship
# * support boxes
# * helped VARs with tools to gain insight into customer systems

# %% [markdown]
# ## VAR challenges
#
# ### initial sales
# * VARs got delayed, didn't sell until product launched
# * needed to get them to start!
#
# ### sales pipeline visability
# * all customer info comes from VARs
# * obligated VARs to give forecasts
# * reseller takes the title of the inventory, so Vocera's brand wasn't at risk?
#
# ### non performing VARs
# * a few VARs didn't pan out
# * a VAR went radio silent. Investments gone...
